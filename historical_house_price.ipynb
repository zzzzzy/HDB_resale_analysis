# %%
import pandas as pd
import os

# %%
path = './raw/resale-flat-prices'

# %%
dfs = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        print(file)
        file_path = os.path.join(path, file)
        temp = pd.read_csv(file_path)
        temp = temp.drop(['remaining_lease'], axis=1, errors='ignore')
        print(temp.shape)
        dfs.append(temp)
# Out:
# resale-flat-prices-based-on-registration-date-from-mar-2012-to-dec-2014.csv
# (52203, 10)
# resale-flat-prices-based-on-approval-date-1990-1999.csv
# (287200, 10)
# resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv
# (97043, 10)
# resale-flat-prices-based-on-approval-date-2000-feb-2012.csv
# (369651, 10)
# resale-flat-prices-based-on-registration-date-from-jan-2015-to-dec-2016.csv
# (37153, 10)

# %%
full = pd.concat(dfs,axis=0)

# %%
full['psm'] = full['resale_price']/full['floor_area_sqm']
full['flat_type'] = full['flat_type'].str.lower()
full['flat_model'] = full['flat_model'].str.lower()
full['year'] = full['month'].apply(lambda x: x.split('-')[0]).astype(int)

# %%
full.flat_type.unique()
# Out:
# array(['2 room', '3 room', '4 room', '5 room', 'executive',
#        'multi-generation', '1 room', 'multi generation'], dtype=object)

# %%
filter_stats_all = full.reset_index().groupby(['town','street_name','block','storey_range',
       'floor_area_sqm', 'flat_type','flat_model', 'lease_commence_date'])['index'].count().reset_index()
filter_stats_all.columns = ['town', 'street_name', 'block', 'storey_range', 'floor_area_sqm','flat_type',
       'flat_model', 'lease_commence_date', 'count']

# %%
filter_stats_2013 = full[full.year>=2013].reset_index().groupby(['town','street_name','block','storey_range',
       'floor_area_sqm', 'flat_type','flat_model', 'lease_commence_date'])['index'].count().reset_index()
filter_stats_2013.columns = ['town', 'street_name', 'block', 'storey_range', 'floor_area_sqm','flat_type',
       'flat_model', 'lease_commence_date', 'count_2013']

# %%
filter_stats = pd.merge(filter_stats_all,filter_stats_2013,on=['town','street_name','block','storey_range',
       'floor_area_sqm', 'flat_type','flat_model', 'lease_commence_date'],how='inner')

# %%
filter_stats = filter_stats[(filter_stats['count']>=5) & (filter_stats['count_2013']>2)].reset_index(drop=True)

# %%
unique_address = pd.read_excel('unique_address_geocode.xlsx')

# %%
full_filtered = pd.merge(filter_stats,full, on=['town','block','street_name','storey_range',
       'floor_area_sqm', 'flat_type','flat_model', 'lease_commence_date'],how='inner')
full_filtered = pd.merge(full_filtered,unique_address[['block','street_name','official_address','lat','lng',
                                            'station_no','station_name','station_color','station_distance_km',
                                            '1km_top50_school_count','1km_top50_schools']], 
                            how='left', on=['block','street_name'])

# %%
town_focus_tier1 = ['BISHAN', 'BUKIT MERAH','BUKIT TIMAH','CLEMENTI', 'KALLANG/WHAMPOA', 
                    'MARINE PARADE', 'QUEENSTOWN', 'TOA PAYOH']

# %%
full_filtered = full_filtered[(full_filtered['1km_top50_school_count']>=1)
                              & (full_filtered.station_distance_km<=1)
                              & (full_filtered.town.isin(town_focus_tier1))
                              & (full_filtered.floor_area_sqm>=85)
                              & (full_filtered.flat_type.isin(['4 room', '5 room']))
                             &(full_filtered.lease_commence_date>1990)]

# %%
full_stats = full_filtered.groupby(['town','block','street_name','storey_range',
       'floor_area_sqm', 'flat_type','flat_model', 'lease_commence_date','year']).agg({'psm':'median'}).reset_index()

# %%
full_stats.head()
# Out:
#      town block   street_name storey_range  floor_area_sqm flat_type  \
# 0  BISHAN   209  BISHAN ST 23     10 TO 12           103.0    4 room
# 1  BISHAN   209  BISHAN ST 23     10 TO 12           103.0    4 room
# 2  BISHAN   209  BISHAN ST 23     10 TO 12           103.0    4 room
# 3  BISHAN   209  BISHAN ST 23     10 TO 12           103.0    4 room
# 4  BISHAN   209  BISHAN ST 23     10 TO 12           103.0    4 room
#
#   flat_model  lease_commence_date  year          psm
# 0    model a                 1992  1996  4223.300971
# 1    model a                 1992  2000  3398.058252
# 2    model a                 1992  2002  3126.213592
# 3    model a                 1992  2005  2975.728155
# 4    model a                 1992  2008  3980.582524

# %%
full_stats.columns
# Out:
# Index(['town', 'block', 'street_name', 'storey_range', 'floor_area_sqm',
#        'flat_type', 'flat_model', 'lease_commence_date', 'year', 'psm'],
#       dtype='object')

# %%
full_stats['cagr'] = None
full_stats['cagr_yr'] = None

# %%
for i in range(1,full_stats.shape[0]):
    if (full_stats.loc[i-1,['town', 'block', 'street_name', 'storey_range', 'floor_area_sqm',
       'flat_type', 'flat_model', 'lease_commence_date']] == full_stats.loc[i,['town', 'block', 'street_name', 'storey_range', 'floor_area_sqm',
       'flat_type', 'flat_model', 'lease_commence_date']]).all():
        t = full_stats.loc[i,'year'] - full_stats.loc[i-1,'year']
        cagr = (full_stats.loc[i,'psm']/full_stats.loc[i-1,'psm'])**(1/t)-1
        full_stats.loc[i,'cagr'] = cagr
        full_stats.loc[i,'cagr_yr'] = t

# %%
cagr_stats = full_stats.dropna()
cagr_stats['cagr'] = cagr_stats['cagr'].astype(float)
# Out:
# /Users/ZhangYing/anaconda3/envs/re/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cagr_stats['post_2013'] = cagr_stats['year'].apply(lambda x: True if x>=2013 else False)
cagr_stats = cagr_stats[cagr_stats['post_2013']==True]
# Out:
# /Users/ZhangYing/anaconda3/envs/re/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
post_2013_cagr = cagr_stats.groupby(['town','flat_type','lease_commence_date','cagr_yr'])['cagr'].median().reset_index()

# %%
post_2013_cagr.pivot_table(index=['town','flat_type','lease_commence_date'], columns='cagr_yr', values='cagr').reset_index().to_excel('cagr_summary.xlsx')

# %%
full.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2012-03  ANG MO KIO    2 room   172   ANG MO KIO AVE 4     06 TO 10
# 1  2012-03  ANG MO KIO    2 room   510   ANG MO KIO AVE 8     01 TO 05
# 2  2012-03  ANG MO KIO    3 room   610   ANG MO KIO AVE 4     06 TO 10
# 3  2012-03  ANG MO KIO    3 room   474  ANG MO KIO AVE 10     01 TO 05
# 4  2012-03  ANG MO KIO    3 room   604   ANG MO KIO AVE 5     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            45.0        improved                 1986      250000.0
# 1            44.0        improved                 1980      265000.0
# 2            68.0  new generation                 1980      315000.0
# 3            67.0  new generation                 1984      320000.0
# 4            67.0  new generation                 1980      321000.0
#
#            psm  year
# 0  5555.555556  2012
# 1  6022.727273  2012
# 2  4632.352941  2012
# 3  4776.119403  2012
# 4  4791.044776  2012

# %%
full[(full.street_name.str.contains('BENDEMEER')) &(full.block.str.contains('39')) & (full.flat_type=='4 room')].sort_values('month')
# Out:
#          month             town flat_type block   street_name storey_range  \
# 12437  2015-09  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     16 TO 18
# 22857  2016-04  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     25 TO 27
# 22854  2016-04  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     19 TO 21
# 24718  2016-05  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     16 TO 18
# 24717  2016-05  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     16 TO 18
# 24708  2016-05  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     01 TO 03
# 28212  2016-07  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     07 TO 09
# 35030  2016-11  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     22 TO 24
# 3204   2017-03  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     16 TO 18
# 3205   2017-03  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     25 TO 27
# 5117   2017-04  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     13 TO 15
# 7018   2017-05  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     04 TO 06
# 8881   2017-06  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     04 TO 06
# 12507  2017-08  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     10 TO 12
# 14300  2017-09  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     19 TO 21
# 16084  2017-10  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     04 TO 06
# 29249  2018-06  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     07 TO 09
# 29247  2018-06  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     16 TO 18
# 31465  2018-07  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     01 TO 03
# 52997  2019-05  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     04 TO 06
# 53010  2019-12  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     10 TO 12
# 75414  2020-03  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     19 TO 21
# 75417  2020-06  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     13 TO 15
# 92051  2021-03  KALLANG/WHAMPOA    4 room   39A  BENDEMEER RD     07 TO 09
#
#        floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 12437            89.0    model a                 2012      725000.0
# 22857            92.0    model a                 2012      745000.0
# 22854            92.0    model a                 2012      715000.0
# 24718            92.0    model a                 2012      695000.0
# 24717            92.0    model a                 2012      685000.0
# 24708            92.0    model a                 2012      595000.0
# 28212            92.0    model a                 2012      668000.0
# 35030            89.0    model a                 2012      690000.0
# 3204             92.0    model a                 2012      680000.0
# 3205             92.0    model a                 2012      701888.0
# 5117             92.0    model a                 2012      680000.0
# 7018             89.0    model a                 2012      650000.0
# 8881             92.0    model a                 2012      625000.0
# 12507            92.0    model a                 2012      680000.0
# 14300            92.0    model a                 2012      692000.0
# 16084            92.0    model a                 2012      610000.0
# 29249            89.0    model a                 2012      750000.0
# 29247            92.0    model a                 2012      688000.0
# 31465            92.0    model a                 2012      585000.0
# 52997            92.0    model a                 2012      580000.0
# 53010            92.0    model a                 2012      735000.0
# 75414            92.0    model a                 2012      733000.0
# 75417            89.0    model a                 2012      733888.0
# 92051            89.0    model a                 2012      650000.0
#
#                psm  year
# 12437  8146.067416  2015
# 22857  8097.826087  2016
# 22854  7771.739130  2016
# 24718  7554.347826  2016
# 24717  7445.652174  2016
# 24708  6467.391304  2016
# 28212  7260.869565  2016
# 35030  7752.808989  2016
# 3204   7391.304348  2017
# 3205   7629.217391  2017
# 5117   7391.304348  2017
# 7018   7303.370787  2017
# 8881   6793.478261  2017
# 12507  7391.304348  2017
# 14300  7521.739130  2017
# 16084  6630.434783  2017
# 29249  8426.966292  2018
# 29247  7478.260870  2018
# 31465  6358.695652  2018
# 52997  6304.347826  2019
# 53010  7989.130435  2019
# 75414  7967.391304  2020
# 75417  8245.932584  2020
# 92051  7303.370787  2021

# %%
full[(full.street_name.str.contains('BENDEMEER')) &(full.block.str.contains('38')) & (full.flat_type=='4 room')].sort_values('month')
# Out:
#          month             town flat_type block   street_name storey_range  \
# 689    2015-01  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     10 TO 12
# 3124   2015-03  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     10 TO 12
# 4653   2015-04  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     10 TO 12
# 6209   2015-05  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     13 TO 15
# 6210   2015-05  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     19 TO 21
# 7923   2015-06  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     22 TO 24
# 10975  2015-08  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     13 TO 15
# 12434  2015-09  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     10 TO 12
# 12436  2015-09  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     19 TO 21
# 14116  2015-10  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     07 TO 09
# 15693  2015-11  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     10 TO 12
# 15694  2015-11  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     07 TO 09
# 15695  2015-11  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     19 TO 21
# 15696  2015-11  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     19 TO 21
# 17106  2015-12  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     13 TO 15
# 17109  2015-12  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     04 TO 06
# 17108  2015-12  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     16 TO 18
# 17107  2015-12  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     07 TO 09
# 18471  2016-01  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     16 TO 18
# 19706  2016-02  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     10 TO 12
# 21145  2016-03  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     19 TO 21
# 22853  2016-04  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     04 TO 06
# 26515  2016-06  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     19 TO 21
# 26516  2016-06  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     16 TO 18
# 26519  2016-06  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     22 TO 24
# 28214  2016-07  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     10 TO 12
# 29997  2016-08  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     16 TO 18
# 29998  2016-08  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     19 TO 21
# 33432  2016-10  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     01 TO 03
# 35029  2016-11  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     19 TO 21
# ...        ...              ...       ...   ...           ...          ...
# 29245  2018-06  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     04 TO 06
# 33738  2018-08  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     22 TO 24
# 33731  2018-08  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     10 TO 12
# 35805  2018-09  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     01 TO 03
# 37784  2018-10  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     16 TO 18
# 41336  2018-12  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     16 TO 18
# 52675  2019-01  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     16 TO 18
# 52679  2019-01  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     07 TO 09
# 52806  2019-04  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     07 TO 09
# 52995  2019-05  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     16 TO 18
# 52998  2019-05  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     13 TO 15
# 52999  2019-06  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     01 TO 03
# 53000  2019-06  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     13 TO 15
# 53001  2019-06  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     04 TO 06
# 53002  2019-06  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     07 TO 09
# 53003  2019-09  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     16 TO 18
# 53004  2019-10  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     10 TO 12
# 53005  2019-10  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     16 TO 18
# 53007  2019-11  KALLANG/WHAMPOA    4 room   38A  BENDEMEER RD     13 TO 15
# 53008  2019-11  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     19 TO 21
# 53006  2019-11  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     04 TO 06
# 53009  2019-12  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     13 TO 15
# 75416  2020-05  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     04 TO 06
# 75418  2020-08  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     16 TO 18
# 75420  2020-11  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     10 TO 12
# 75421  2020-12  KALLANG/WHAMPOA    4 room   38C  BENDEMEER RD     04 TO 06
# 92048  2021-01  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     16 TO 18
# 92049  2021-03  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     10 TO 12
# 92050  2021-03  KALLANG/WHAMPOA    4 room   38B  BENDEMEER RD     10 TO 12
# 92052  2021-04  KALLANG/WHAMPOA    4 room   38D  BENDEMEER RD     16 TO 18
#
#        floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 689              92.0    model a                 2012      650000.0
# 3124             92.0    model a                 2012      680000.0
# 4653             92.0    model a                 2012      675000.0
# 6209             92.0    model a                 2012      695000.0
# 6210             92.0    model a                 2012      730000.0
# 7923             92.0    model a                 2012      728000.0
# 10975            89.0    model a                 2012      696000.0
# 12434            92.0    model a                 2012      688000.0
# 12436            92.0    model a                 2012      720000.0
# 14116            89.0    model a                 2012      627000.0
# 15693            89.0    model a                 2012      680000.0
# 15694            92.0    model a                 2012      688000.0
# 15695            89.0    model a                 2012      695000.0
# 15696            89.0    model a                 2012      698000.0
# 17106            92.0    model a                 2012      695000.0
# 17109            89.0    model a                 2012      628000.0
# 17108            92.0    model a                 2012      742000.0
# 17107            89.0    model a                 2012      650000.0
# 18471            92.0    model a                 2012      730000.0
# 19706            92.0    model a                 2012      668000.0
# 21145            89.0    model a                 2012      702000.0
# 22853            89.0    model a                 2012      615000.0
# 26515            89.0    model a                 2012      690000.0
# 26516            89.0    model a                 2012      692000.0
# 26519            89.0    model a                 2012      713000.0
# 28214            92.0    model a                 2012      690000.0
# 29997            89.0    model a                 2012      680000.0
# 29998            89.0    model a                 2012      705000.0
# 33432            92.0    model a                 2012      580000.0
# 35029            89.0    model a                 2012      690000.0
# ...               ...        ...                  ...           ...
# 29245            89.0    model a                 2012      650000.0
# 33738            89.0    model a                 2012      737500.0
# 33731            89.0    model a                 2012      582000.0
# 35805            89.0    model a                 2012      555000.0
# 37784            89.0    model a                 2012      699000.0
# 41336            92.0    model a                 2012      735000.0
# 52675            89.0    model a                 2012      686888.0
# 52679            92.0    model a                 2012      720000.0
# 52806            89.0    model a                 2012      670000.0
# 52995            89.0    model a                 2012      750000.0
# 52998            89.0    model a                 2012      708000.0
# 52999            89.0    model a                 2012      580000.0
# 53000            89.0    model a                 2012      710000.0
# 53001            89.0    model a                 2012      700000.0
# 53002            92.0    model a                 2012      678000.0
# 53003            89.0    model a                 2012      738000.0
# 53004            92.0    model a                 2012      715000.0
# 53005            92.0    model a                 2012      621000.0
# 53007            92.0    model a                 2012      725500.0
# 53008            92.0    model a                 2012      760000.0
# 53006            89.0    model a                 2012      558000.0
# 53009            89.0    model a                 2012      733000.0
# 75416            89.0    model a                 2012      663888.0
# 75418            89.0    model a                 2012      717168.0
# 75420            92.0    model a                 2012      710000.0
# 75421            92.0    model a                 2012      678000.0
# 92048            89.0    model a                 2012      758888.0
# 92049            89.0    model a                 2012      705000.0
# 92050            89.0    model a                 2012      705000.0
# 92052            89.0    model a                 2012      733000.0
#
#                psm  year
# 689    7065.217391  2015
# 3124   7391.304348  2015
# 4653   7336.956522  2015
# 6209   7554.347826  2015
# 6210   7934.782609  2015
# 7923   7913.043478  2015
# 10975  7820.224719  2015
# 12434  7478.260870  2015
# 12436  7826.086957  2015
# 14116  7044.943820  2015
# 15693  7640.449438  2015
# 15694  7478.260870  2015
# 15695  7808.988764  2015
# 15696  7842.696629  2015
# 17106  7554.347826  2015
# 17109  7056.179775  2015
# 17108  8065.217391  2015
# 17107  7303.370787  2015
# 18471  7934.782609  2016
# 19706  7260.869565  2016
# 21145  7887.640449  2016
# 22853  6910.112360  2016
# 26515  7752.808989  2016
# 26516  7775.280899  2016
# 26519  8011.235955  2016
# 28214  7500.000000  2016
# 29997  7640.449438  2016
# 29998  7921.348315  2016
# 33432  6304.347826  2016
# 35029  7752.808989  2016
# ...            ...   ...
# 29245  7303.370787  2018
# 33738  8286.516854  2018
# 33731  6539.325843  2018
# 35805  6235.955056  2018
# 37784  7853.932584  2018
# 41336  7989.130435  2018
# 52675  7717.842697  2019
# 52679  7826.086957  2019
# 52806  7528.089888  2019
# 52995  8426.966292  2019
# 52998  7955.056180  2019
# 52999  6516.853933  2019
# 53000  7977.528090  2019
# 53001  7865.168539  2019
# 53002  7369.565217  2019
# 53003  8292.134831  2019
# 53004  7771.739130  2019
# 53005  6750.000000  2019
# 53007  7885.869565  2019
# 53008  8260.869565  2019
# 53006  6269.662921  2019
# 53009  8235.955056  2019
# 75416  7459.415730  2020
# 75418  8058.067416  2020
# 75420  7717.391304  2020
# 75421  7369.565217  2020
# 92048  8526.831461  2021
# 92049  7921.348315  2021
# 92050  7921.348315  2021
# 92052  8235.955056  2021
#
# [85 rows x 12 columns]
